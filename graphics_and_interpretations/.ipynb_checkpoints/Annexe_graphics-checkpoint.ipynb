# %% [markdown]
# # Graphical representations for Annexe

# %% [markdown]
# ## Imports

# %%
import sys
import os
import os.path
import io
import csv
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.stats import gamma
from scipy import integrate
import seaborn as sns
import numpy.random as nprand
from scipy.stats import gamma

# %% [markdown]
# ## Usefull functions

# %%
#simpson method
def simpson(f, a, b, n): 
    pas = (b - a) / n
    somme = (f(a) + f(b)) / 2 + 2 * f(a + pas / 2)  # We initialize the sum
    x = a + pas           # The sum begins at x_1 
    for i in range(1, n): # It computes the sum 
        somme += f(x) + 2 * f(x + pas / 2)
        x += pas
    return somme * pas / 3   # It returns this sum times the step / 3

# %%
# Gamma function
c=1
coeff_gamma=0.6
def gamma_func(aff):
    integral=1/coeff_gamma*np.exp(-aff*1/coeff_gamma)
    return integral

# Numercial computation of the moments <x^n>_0
def x_0_func(aff):
    integral=(c*aff)/(1+c*aff)*gamma_func(aff)
    return integral
def x2_0_func(aff):
    integral=((c*aff)/(1+c*aff))**2*gamma_func(aff)
    return integral
def x3_0_func(aff):
    integral=((c*aff)/(1+c*aff))**3*gamma_func(aff)
    return integral
def x4_0_func(aff):
    integral=((c*aff)/(1+c*aff))**4*gamma_func(aff)
    return integral

# %% [markdown]
# ## Binding probability in function of affinity

# %%
affinity=list(range(0, 10000, 1))
affinity1=[]
gamma_list=[]
link_list=[]
link_hom_list=[]
diff_link_list=[]
for i in range(len(affinity)):
    y=affinity[i]/1000
    affinity1.append(y)
    gamma_list.append(gamma_func(y))
    link_list.append(y/(1+y))
    link_hom_list.append(2*y/(1+2*y))
    diff_link_list.append(link_hom_list[i]-link_list[i])

# Figure
figure=plt.figure(1, figsize=(5,3))
figure.patch.set_facecolor('white')
figure.patch.set_alpha(0)
plt.xlabel("Binding affinity (y)", fontsize = 12)
plt.ylabel("Binding probability (x)", fontsize = 12)
plt.plot(affinity1,link_list,label="Heterozygotes (y/(1+y))",color='#377eb8')
plt.plot(affinity1,link_hom_list,label="Homozygotes (2y/(1+2y))",color='#e41a1c')
plt.xscale("log")
#plt.yscale("log")
plt.grid()
plt.legend()

# %%
# Figure
figure=plt.figure(1, figsize=(5,3))
figure.patch.set_facecolor('white')
figure.patch.set_alpha(0)
plt.xlabel("y", fontsize = 12)
plt.ylabel("x_hom - x_het", fontsize = 12)
plt.plot(affinity1,diff_link_list,color='#ff7f00')
plt.xscale("log")
plt.yscale("log")
plt.axvline(np.sqrt(1/2),color="black")
plt.grid()
print(np.sqrt(1/2))
# Out:
# 0.7071067811865476

# %% [markdown]
# ## Binding probability in function of free PRDM9 concentration

# %%
concentration=list(range(0, 5000, 1))
concentration1=[]
gamma_list=[]
link_list=[]
link_hom_list=[]
for i in range(len(concentration)):
    c=concentration[i]
    concentration1.append(c)
    link_list.append(c*0.6/(1+c*0.6))
    link_hom_list.append(2*c*0.6/(1+2*c*0.6))

# Figure
plt.figure(1, figsize=(5,3))
figure.patch.set_facecolor('white')
figure.patch.set_alpha(0)
plt.xlabel("Free PRDM9 concentration (cfree)", fontsize = 12)
plt.ylabel("Binding probability (x)", fontsize = 12)
plt.plot(concentration1,link_list,label="Heterozygotes",color='#377eb8')
plt.plot(concentration1,link_hom_list,label="Homozygotes",color='#e41a1c')
plt.legend()
plt.xscale("log")
plt.yscale("log")
plt.grid(axis="x")
plt.grid(axis="y",which="minor")

plt.savefig('Fig_1_Sup.png', dpi=200, bbox_inches='tight')

# %% [markdown]
# ## Finding the empirical mean affinity

# %%
c=2
nbhotsopt=20000
coeff=list(range(0, 500, 1))
print(len(coeff))
j=0
probalink=0
while (probalink<5000 and j<len(coeff)):
    x=nprand.exponential(coeff[j]/100, nbhotsopt)
    probalink=0
    for i in range(nbhotsopt):
        probalink+=c*x[i]/(1+c*x[i])
    j+=1

# Print results
print("Mean Affinity = ",coeff[j]/100)
print("Number of bound sites = ",probalink)
print("lambda = ",1/(coeff[j]/100)) # lambda is the parameter for exponential law
# Out:
# 500
# Mean Affinity =  0.23
# Number of bound sites =  5147.156420502589
# lambda =  4.3478260869565215

# %%
# import exponential
import numpy as np
import matplotlib.pyplot as plt
  
# Using exponential() method
gfg = np.random.exponential(0.22, 20000) #=> The first parameter corresponds to 1/lambda = E(X)
print("lambda = ",1/0.22)
  
count, bins, ignored = plt.hist(gfg, 100, density = True)
plt.axvline(x=0.22,color="black")
plt.show()
# Out:
# lambda =  4.545454545454546

# %%
# Verifications
c=2
coeff=0.22
nbhotsopt=20000
x=nprand.exponential(coeff, nbhotsopt)
probalink=0
for i in range(nbhotsopt):
    probalink+=c*x[i]/(1+c*x[i])
print(probalink)
# Out:
# 5135.218336445075
