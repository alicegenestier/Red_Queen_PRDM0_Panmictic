# %% [markdown]
# # Heatmap scaling 2D ctot affinity

# %%
import sys
import os
import os.path
import io
import csv
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.stats import gamma
from scipy import integrate
import seaborn as sns
import numpy.random as nprand

# plt.rcParams.update({'font.size': 16})
from scipy.stats import gamma

# %%
init_path="../../../"

# %%
def readfiles1(pathtofile, file_name, ext_name,withoutneutral,withoutnan,minq,minfert,logfert,line_to_begin):
    data_file = pathtofile+file_name+"."+ext_name
    data = dict()
    params = []
    nbline=1
    with io.open(data_file,'r') as f:
        reader = csv.reader(f)
        firstline = True
        for line in reader:
            lin = line[0].split()
            if not firstline:
                if nbline>=line_to_begin:
                    for j in range(len(lin)):
                        if ext_name == "allele":
                            if float(lin[5])>minq and float(lin[6])>minfert:
                                if withoutneutral==1 and float(lin[1]) != -3 :
                                    if withoutnan == 0:
                                        if logfert==True and (j==6 or j==9):
                                            data[params[j]].append(np.log(float(lin[j])))
                                        else:
                                            data[params[j]].append(float(lin[j]))
                                    elif withoutnan ==1 :
                                        if lin[5]!="-nan" and lin[6]!="-nan":
                                            if logfert==True and (j==6 or j==9):
                                                data[params[j]].append(np.log(float(lin[j])))
                                            else:
                                                data[params[j]].append(float(lin[j])) 
                                elif withoutneutral==0:
                                    if withoutnan == 0:
                                        if logfert==True and (j==6 or j==9):
                                            data[params[j]].append(np.log(float(lin[j])))
                                        else:
                                            data[params[j]].append(float(lin[j]))
                                    elif withoutnan ==1 :
                                        if lin[5]!="-nan" and lin[6]!="-nan":
                                            if logfert==True and (j==6 or j==9):
                                                data[params[j]].append(np.log(float(lin[j])))
                                            else:
                                                data[params[j]].append(float(lin[j]))
                        elif ext_name == "trace" and logfert==True and (j==6 or j==14):
                            data[params[j]].append(np.log(float(lin[j])))
                        else :
                            data[params[j]].append(float(lin[j]))
                nbline=nbline+1
            else:
                for j in lin:
                    data[j]=[]
                    params.append(j)
                firstline = False
                nbline=nbline+1
    return (data)

# %%
def readparamsfile(pathtofile, file_name, ext_name):
    data_file = pathtofile+file_name+"."+ext_name
    data = dict()
    params = []
    with io.open(data_file,'r') as f:
        reader = csv.reader(f)
        for line in reader:
            lin = line[0].split()
            data[lin[0]]=[]
            data[lin[0]].append(float(lin[1]))
    return (data)

# %%
N=5000
u=2e-4
v=2e-5
h=400
d=6
coeff_gamma=0.6
c=1

# %%
def dico_data(target_folder_path,x_params,y_params, file_ext, withneutral,withoutnan,withlog,initline):
    list_files = sorted(os.listdir(target_folder_path))
    dico_file = dict()
    list_namefile=[]
    for file_name in list_files :
        if file_name.split(".")[1]==file_ext :
            if withneutral==1:
                data_file=readfiles(target_folder_path, file_name.split(".")[0], file_name.split(".")[1],0,withoutnan)
            elif withneutral==0:
                data_file=readfiles1(target_folder_path, file_name.split(".")[0], file_name.split(".")[1],1,withoutnan,0,0,withlog,initline)
            if  x_params in data_file and y_params in data_file :
                dico_file[(file_name.split(".")[0]).split("_")[-1]+"_x_params"]=data_file[x_params]
                dico_file[(file_name.split(".")[0]).split("_")[-1]+"_y_params"]=data_file[y_params]
            list_namefile.append((file_name.split(".")[0]).split("_")[2])
    list_namefile=sorted(list(set(list_namefile)))
    #print(len(data_file[y_params]))
    #print(len(data_file[x_params]))
    #print(data_file1[y_params])
    return (list_namefile,dico_file)

# %%
def simpson(f, a, b, n,coeff_gamma,c):
    pas = (b - a) / n
    somme = (f(a,coeff_gamma,c) + f(b,coeff_gamma,c)) / 2 + 2 * f(a + pas / 2,coeff_gamma,c)  # On initialise la somme
    x = a + pas           # La somme commence à x_1 
    for i in range(1, n): # On calcule la somme 
        somme += f(x,coeff_gamma,c) + 2 * f(x + pas / 2,coeff_gamma,c)
        x += pas
    return somme * pas / 3   # On retourne cette somme fois le pas / 3  

#c=1
#c=2
#coeff_gamma=0.6
coeff_gamma=0.6
c=1
def gamma_func(aff,coeff_gamma):
    integral=1/coeff_gamma*np.exp(-aff*1/coeff_gamma)
    return integral

def x_0_func(aff,coeff_gamma,c):
    integral=(c*aff)/(1+c*aff)*gamma_func(aff,coeff_gamma)
    return integral
def x2_0_func(aff,coeff_gamma,c):
    integral=((c*aff)/(1+c*aff))**2*gamma_func(aff,coeff_gamma)
    return integral
def x3_0_func(aff,coeff_gamma,c):
    integral=((c*aff)/(1+c*aff))**3*gamma_func(aff,coeff_gamma)
    return integral
def x4_0_func(aff,coeff_gamma,c):
    integral=((c*aff)/(1+c*aff))**4*gamma_func(aff,coeff_gamma)
    return integral


def x_bar_func(aff):
    integral=(c*aff)/(1+c*aff)*gamma_func(aff,coeff_gamma)*np.exp(-((c*aff)/(1+c*aff))/(x_0)*z_bar)
    return integral
def x2_bar_func(aff):
    integral=((c*aff)/(1+c*aff))**2*gamma_func(aff,coeff_gamma)*np.exp(-((c*aff)/(1+c*aff))/(x_0)*z_bar)
    return integral
def x3_bar_func(aff):
    integral=((c*aff)/(1+c*aff))**3*gamma_func(aff,coeff_gamma)*np.exp(-((c*aff)/(1+c*aff))/(x_0)*z_bar)
    return integral

# %%
x_0=simpson(x_0_func, 0, 100, 1000,coeff_gamma,c)
x2_0=simpson(x2_0_func, 0, 100, 1000,coeff_gamma,c)
x3_0=simpson(x3_0_func, 0, 100, 1000,coeff_gamma,c)
x4_0=simpson(x4_0_func, 0, 100, 1000,coeff_gamma,c)
q_0=(2*x2_0-x3_0)/(x_0)
w_0=1-np.exp(-d*q_0)###############################
beta_0=(-2*x3_0+x4_0+(2*x2_0**2)/(x_0)-(x3_0*x2_0)/(x_0))/(2*x_0**2)
alpha=abs((1/w_0)*d*beta_0*np.exp(-d*q_0))############################
rho=(N*v*d)/(2*h)
mu=4*N*u
z_bar=np.sqrt(rho/(mu*alpha))

# %%
def s0_def(list_namefile_age,dico_file_age,list_namefile_freq,dico_file_freq):
    #print(list_namefile_age)
    S0=[]
    for i in list_namefile_age :
        fert_moy=0
        n=len(dico_file_age[i+"_x_params"])
        m=min(dico_file_age[i+"_x_params"])
        ntot=0
        for j in range(n):
            if dico_file_age[i+"_x_params"][j]==m and dico_file_age[i+"_y_params"][j]!=0:
                fert_moy+=dico_file_age[i+"_y_params"][j]
                ntot+=1
        fertility_new_all=fert_moy/ntot
        #print(fertility_new_all)# = fert_0?
        #print(np.mean(dico_file_age[i+"_y_params"]))# = w_bar ?
        meanfert=0
        for j in range(len(dico_file_age[i+"_y_params"])):
            meanfert=meanfert+dico_file_freq[i+"_y_params"][j]*dico_file_freq[i+"_x_params"][j]
        #print(meanfert/(31-14))
        #print(sum(dico_file1[i+"_x_params"])/(84-35))
        fert_moy=np.log(fert_moy/ntot)-np.log(np.mean(dico_file_age[i+"_y_params"]))
        S0.append(fert_moy)
    return(S0)

# %%
def sigmatau_def(u,v,d,coeff_gamma,c,target_folder_path,file_name,sig):
    x_0=simpson(x_0_func, 0, 100, 1000,coeff_gamma,c)
    x2_0=simpson(x2_0_func, 0, 100, 1000,coeff_gamma,c)
    x3_0=simpson(x3_0_func, 0, 100, 1000,coeff_gamma,c)
    x4_0=simpson(x4_0_func, 0, 100, 1000,coeff_gamma,c)
    q_0=(2*x2_0-x3_0)/(x_0)
    w_0=1-np.exp(-d*q_0)###############################
    beta_0=(-2*x3_0+x4_0+(2*x2_0**2)/(x_0)-(x3_0*x2_0)/(x_0))/(2*x_0**2)
    alpha=abs((1/w_0)*d*beta_0*np.exp(-d*q_0))############################
    rho=(N*v*d)/(2*h)
    mu=4*N*u
    z_bar=np.sqrt(rho/(mu*alpha))
    DTau=np.sqrt(mu/(rho*alpha))
    Tau=2*np.sqrt(1/(rho*mu*alpha))
    s0=alpha*z_bar/2
    if sig==1:
        sigma=float(readparamsfile(target_folder_path, file_name, 'params')['sigma_0'][0])
    else :
        sigma=float(readparamsfile(target_folder_path, file_name, 'params')['Sigma_0'][0])
    return(sigma*Tau,Tau,sigma,s0)

# %%
withoutneutral=0
logfert=0
key="Diversity"
key1="q"
key2="Fertility_rate"
key3="cfree_ctot_hom"
key4="cfree_ctot_het"
key5="Mean_c_free_het"
key6="Mean_c_free_hom"
key7="Activity"
key8="mean_affinity"
key9="Mean_sigma"
init_line=100
c=1
def heatmap_Div_ctot(target_folder_path, key, logfert, withoutneutral, init_line,c):
    list_dir = sorted(os.listdir(target_folder_path))
    #print(list_files)
    data = dict()
    sigmatau = dict()
    Nu = dict()
    sigdtau = dict()
    tau = dict()
    sig0 = dict()
    Ns0 = dict()
    fourNs0 = dict()
    q=dict()
    fert=dict()
    sigma=dict()
    tau=dict()
    cfree_ctot_hom=dict()
    cfree_ctot_het=dict()
    cfree_hom=dict()
    cfree_het=dict()
    q_0_hom=dict()
    q_0_het=dict()
    Mean_cfree_het=dict()
    Mean_cfree_hom=dict()
    cfree_aff_het=dict()
    cfree_aff_hom=dict()
    activity=dict()
    mean_affinity=dict()
    cfree_meanaff_eq_het=dict()
    cfree_meanaff_eq_hom=dict()
    sigma_z=dict()
    col_names=[]
    list_index=[]
    first_loop=0
    for dir_name in list_dir :
        list_index=[]
        data[float(dir_name.split("_")[2])]=[]
        sigmatau[float(dir_name.split("_")[2])]=[]
        sigma[float(dir_name.split("_")[2])]=[]
        Nu[float(dir_name.split("_")[2])]=[]
        sigdtau[float(dir_name.split("_")[2])] = []
        tau[float(dir_name.split("_")[2])] = []
        sig0[float(dir_name.split("_")[2])] = []
        Ns0[float(dir_name.split("_")[2])] = []
        q[float(dir_name.split("_")[2])]=[]
        fert[float(dir_name.split("_")[2])]=[]
        tau[float(dir_name.split("_")[2])]=[]
        cfree_ctot_hom[float(dir_name.split("_")[2])]=[]
        cfree_ctot_het[float(dir_name.split("_")[2])]=[]
        cfree_hom[float(dir_name.split("_")[2])]=[]
        cfree_het[float(dir_name.split("_")[2])]=[]
        Mean_cfree_het[float(dir_name.split("_")[2])]=[]
        Mean_cfree_hom[float(dir_name.split("_")[2])]=[]
        cfree_aff_het[float(dir_name.split("_")[2])]=[]
        cfree_aff_hom[float(dir_name.split("_")[2])]=[]
        activity[float(dir_name.split("_")[2])]=[]
        mean_affinity[float(dir_name.split("_")[2])]=[]
        cfree_meanaff_eq_het[float(dir_name.split("_")[2])]=[]
        cfree_meanaff_eq_hom[float(dir_name.split("_")[2])]=[]
        sigma_z[float(dir_name.split("_")[2])]=[]
        col_names.append(float((dir_name.split(".")[0]).split("_")[2]))
        list_files = sorted(os.listdir(target_folder_path+'/'+dir_name))
        #print(list_files)
        #
        list_namefile,dico_file=dico_data(target_folder_path+'/'+dir_name+'/',"Age","fertility_analytic","allele",0,1,False,0)
        list_namefile1,dico_file1=dico_data(target_folder_path+'/'+dir_name+'/',"Frequency","fertility_analytic","allele",0,1,False,0)
        #s0_init=s0_def(list_namefile,dico_file,list_namefile1,dico_file1)
        #for ind_s0 in range(len(s0_init)):
            #s0_init[ind_s0]=s0_init[ind_s0]*4*N
        #fourNs0[float(dir_name.split("_")[2])] = s0_def(list_namefile,dico_file,list_namefile1,dico_file1)
        #
        for files_name in list_files :
            if files_name.split(".")[-1]=="trace":
                if files_name.split(".")[1]=="trace":
                    filename=files_name.split(".")[0]
                elif files_name.split(".")[1]!="trace":
                    filename=files_name.split(".")[0]+'.'+files_name.split(".")[1]
                #if first_loop==0:
                list_index.append(float(filename.split("_")[2]))
                data_file = readfiles1(target_folder_path+'/'+dir_name+'/', filename, files_name.split(".")[-1],withoutneutral,0,0,0,logfert,0)
                data[float(dir_name.split("_")[2])].append(np.mean(data_file[key][init_line:]))
                sigmatau[float(dir_name.split("_")[2])].append(sigmatau_def(float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['u'][0]),float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['v'][0]),float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['nbDSB'][0]),float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['meanaff'][0]),c,target_folder_path+'/'+dir_name+'/',filename,1)[0])
                q[float(dir_name.split("_")[2])].append(np.mean(data_file[key1][init_line:]))
                sigma[float(dir_name.split("_")[2])].append(float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['sigma_0'][0]))
                fert[float(dir_name.split("_")[2])].append(np.mean(data_file[key2][init_line:]))
                tau[float(dir_name.split("_")[2])].append(sigmatau_def(float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['u'][0]),float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['v'][0]),float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['nbDSB'][0]),float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['meanaff'][0]),c,target_folder_path+'/'+dir_name+'/',filename,1)[2])
                Mean_cfree_het[float(dir_name.split("_")[2])].append(np.mean(data_file[key5][init_line:]))
                Mean_cfree_hom[float(dir_name.split("_")[2])].append(np.mean(data_file[key6][init_line:]))
                cfree_aff_het[float(dir_name.split("_")[2])].append(np.mean(data_file[key5][init_line:])*float(filename.split("_")[2]))
                cfree_aff_hom[float(dir_name.split("_")[2])].append(np.mean(data_file[key6][init_line:])*float(filename.split("_")[2]))
                activity[float(dir_name.split("_")[2])].append(np.mean(data_file[key7][init_line:]))
                sigma_z[float(dir_name.split("_")[2])].append(np.mean(data_file[key9][init_line:]))
                #cfree_ctot_hom[float(dir_name.split("_")[2])].append(np.mean(data_file[key3][init_line:]))
                #cfree_ctot_het[float(dir_name.split("_")[2])].append(np.mean(data_file[key4][init_line:]))
                #print(data_file)
                #Nu[float(dir_name.split("_")[2])].append(N*float((files_name.split(".")[0]).split("_")[2]))
                #sigdtau[float(dir_name.split("_")[2])].append(sigmatau_def(float((files_name.split(".")[0]).split("_")[2]),float(dir_name.split("_")[2]),target_folder_path+'/'+dir_name+'/',files_name.split(".")[0])[0]*np.mean(data_file[key][init_line:]))
                #tau[float(dir_name.split("_")[2])].append(sigmatau_def(float((files_name.split(".")[0]).split("_")[2]),float(dir_name.split("_")[2]),target_folder_path+'/'+dir_name+'/',files_name.split(".")[0])[1])
                #sig0[float(dir_name.split("_")[2])].append(sigmatau_def(float((files_name.split(".")[0]).split("_")[2]),float(dir_name.split("_")[2]),target_folder_path+'/'+dir_name+'/',files_name.split(".")[0])[2])
                #Ns0[float(dir_name.split("_")[2])].append(sigmatau_def(float((files_name.split(".")[0]).split("_")[2]),float(dir_name.split("_")[2]),target_folder_path+'/'+dir_name+'/',files_name.split(".")[0])[2]*N)
            if files_name.split(".")[-1]=="allele":
                if files_name.split(".")[1]=="allele":
                    filename=files_name.split(".")[0]
                elif files_name.split(".")[1]!="allele":
                    filename=files_name.split(".")[0]+'.'+files_name.split(".")[1]
                data_file = readfiles1(target_folder_path+'/'+dir_name+'/', filename, files_name.split(".")[-1],withoutneutral,0,0,0,logfert,0)
                cfree_ctot_hom[float(dir_name.split("_")[2])].append(np.mean(data_file[key3][init_line:]))
                cfree_ctot_het[float(dir_name.split("_")[2])].append(np.mean(data_file[key4][init_line:])) 
                cfree_hom[float(dir_name.split("_")[2])].append((np.mean(data_file[key3][init_line:]))*float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['ctot'][0])*2)
                cfree_het[float(dir_name.split("_")[2])].append((np.mean(data_file[key4][init_line:]))*float(readparamsfile(target_folder_path+'/'+dir_name+'/', filename, 'params')['ctot'][0]))
                mean_affinity[float(dir_name.split("_")[2])].append((np.mean(data_file[key8][init_line:])))
        #first_loop=1
    for cle, valeur in Mean_cfree_het.items():
        #print(range(len(Mean_cfree_het[cle])))
        for indexvaleur in range(len(Mean_cfree_het[cle])):
            cfree_meanaff_eq_het[cle].append(Mean_cfree_het[cle][indexvaleur]*mean_affinity[cle][indexvaleur])
            cfree_meanaff_eq_hom[cle].append(Mean_cfree_hom[cle][indexvaleur]*mean_affinity[cle][indexvaleur])
            
    return (data,col_names,list_index,sigmatau,Nu,sigdtau,tau,sig0,Ns0,fourNs0,q,sigma,fert,tau,cfree_ctot_hom,cfree_ctot_het,cfree_hom,cfree_het,Mean_cfree_het,Mean_cfree_hom,cfree_aff_het,cfree_aff_hom,activity,cfree_meanaff_eq_het,cfree_meanaff_eq_hom,sigma_z,mean_affinity)

# %%
target_folder_path=init_path+"analyses/scaling_bidim_ctot_aff/scaling_bidim_ctot_aff_2"
(data,col_names,list_index,sigmatau,Nu,sigdtau,tau,sig0,Ns0,fourNs0,q,sigma,fert,tau,cfree_ctot_hom,cfree_ctot_het,cfree_hom,cfree_het,Mean_cfree_het,Mean_cfree_hom,cfree_aff_het,cfree_aff_hom,activity,cfree_meanaff_eq_het,cfree_meanaff_eq_hom,sigma_z,mean_affinity)=heatmap_Div_ctot(target_folder_path, key, logfert, withoutneutral, init_line,c)
# Out:
# /tmp/ipykernel_6364/2001762035.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   q_0=(2*x2_0-x3_0)/(x_0)
# /tmp/ipykernel_6364/2001762035.py:8: RuntimeWarning: invalid value encountered in double_scalars
#   beta_0=(-2*x3_0+x4_0+(2*x2_0**2)/(x_0)-(x3_0*x2_0)/(x_0))/(2*x_0**2)
# /tmp/ipykernel_6364/2001762035.py:8: RuntimeWarning: divide by zero encountered in double_scalars
#   beta_0=(-2*x3_0+x4_0+(2*x2_0**2)/(x_0)-(x3_0*x2_0)/(x_0))/(2*x_0**2)
# /tmp/ipykernel_6364/2001762035.py:15: RuntimeWarning: invalid value encountered in double_scalars
#   s0=alpha*z_bar/2

# %%
#plt.subplots(figsize=(27,10))
df_cfhom_aff = pd.DataFrame(cfree_aff_hom, index = list_index)
df_cfhom_aff_transposed = df_cfhom_aff.transpose()
df_cfhom_aff_transposed=df_cfhom_aff_transposed.sort_index(axis = 0,ascending = False)
df_cfhom_aff_transposed=df_cfhom_aff_transposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_cfhom_aff_transposed,annot=True,vmin=0,vmax=1)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')

#df_cfhom_aff=df_cfhom_aff.sort_index(axis = 0,ascending = False)
#df_cfhom_aff=df_cfhom_aff.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_cfhom_aff,annot=True,vmin=0,vmax=1)

# %%
#plt.subplots(figsize=(27,10))
df_cfhet_aff = pd.DataFrame(cfree_aff_het, index = list_index)
df_cfhet_aff_transposed = df_cfhet_aff.transpose()
df_cfhet_aff_transposed=df_cfhet_aff_transposed.sort_index(axis = 0,ascending = False)
df_cfhet_aff_transposed=df_cfhet_aff_transposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_cfhet_aff_transposed,annot=True,vmin=0,vmax=1)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')


#df_cfhet_aff=df_cfhet_aff.sort_index(axis = 0,ascending = False)
#df_cfhet_aff=df_cfhet_aff.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_cfhet_aff,annot=True,vmin=0,vmax=1)

# %%
#plt.subplots(figsize=(27,10))
df = pd.DataFrame(data, index = list_index)
df_tranposed=df.transpose()
df_tranposed=df_tranposed.sort_index(axis = 0,ascending = False)
df_tranposed=df_tranposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_tranposed,annot=True,vmin=1,vmax=10)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')

# %%
plt.subplots(figsize=(16,7))
df_sigma_0 = pd.DataFrame(sigma, index = list_index)
df_sigma_0_tranposed = df_sigma_0.transpose()
df_sigma_0_tranposed=df_sigma_0_tranposed.sort_index(axis = 0,ascending = False)
df_sigma_0_tranposed=df_sigma_0_tranposed.sort_index(axis = 1,ascending = True)
ax = sns.heatmap(df_sigma_0_tranposed,annot=True,vmin=0,vmax=0.5)
ax.set_title("Sigma0 depending on total concentration of PRDM9 and mean affinity of the targets", fontsize=18)
ax.set_xlabel('Mean affinity of the targets',fontsize=16)
ax.set_ylabel('Total PRDM9 concentration',fontsize=16)
# Out:
# Text(170.72222222222223, 0.5, 'Total PRDM9 concentration')

# %%
#plt.subplots(figsize=(27,10))
df_sigmatau = pd.DataFrame(sigmatau, index = list_index)
df_sigmatau_tranposed = df_sigmatau.transpose()
df_sigmatau_tranposed=df_sigmatau_tranposed.sort_index(axis = 0,ascending = False)
df_sigmatau_tranposed=df_sigmatau_tranposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_sigmatau_tranposed,annot=True,vmin=1,vmax=10)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')

# %%
#plt.subplots(figsize=(27,10))
df_cfhet = pd.DataFrame(cfree_ctot_het, index = list_index)
df_cfhet_tranposed = df_cfhet.transpose()
df_cfhet_tranposed=df_cfhet_tranposed.sort_index(axis = 0,ascending = False)
df_cfhet_tranposed=df_cfhet_tranposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_cfhet_tranposed,annot=True,vmin=0,vmax=1)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')

# %%
#plt.subplots(figsize=(27,10))
df_cfhom = pd.DataFrame(cfree_ctot_hom, index = list_index)
df_cfhom_tranposed = df_cfhom.transpose()
df_cfhom_tranposed=df_cfhom_tranposed.sort_index(axis = 0,ascending = False)
df_cfhom_tranposed=df_cfhom_tranposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_cfhom_tranposed,annot=True,vmin=0,vmax=1)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')

# %%
#plt.subplots(figsize=(27,10))
df_act = pd.DataFrame(activity, index = list_index)
df_act_tranposed = df_act.transpose()
df_act_tranposed=df_act_tranposed.sort_index(axis = 0,ascending = False)
df_act_tranposed=df_act_tranposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_act_tranposed,annot=True,vmin=0,vmax=1)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')

# %%
#plt.subplots(figsize=(27,10))
df_cfree_aff_eq_het = pd.DataFrame(cfree_meanaff_eq_het, index = list_index)
df_cfree_aff_eq_het_tranposed = df_cfree_aff_eq_het.transpose()
df_cfree_aff_eq_het_tranposed=df_cfree_aff_eq_het_tranposed.sort_index(axis = 0,ascending = False)
df_cfree_aff_eq_het_tranposed=df_cfree_aff_eq_het_tranposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_cfree_aff_eq_het_tranposed,annot=True,vmin=0,vmax=1)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')

# %%
#plt.subplots(figsize=(27,10))
df_cfree_aff_eq_hom = pd.DataFrame(cfree_meanaff_eq_hom, index = list_index)
df_cfree_aff_eq_hom_tranposed = df_cfree_aff_eq_hom.transpose()
df_cfree_aff_eq_hom_tranposed=df_cfree_aff_eq_hom_tranposed.sort_index(axis = 0,ascending = False)
df_cfree_aff_eq_hom_tranposed=df_cfree_aff_eq_hom_tranposed.sort_index(axis = 1,ascending = True)
#ax = sns.heatmap(df_cfree_aff_eq_hom_tranposed,annot=True,vmin=0,vmax=1)
#ax.set_xlabel('aff')
#ax.set_ylabel('ctot')

# %%
plt.subplots(figsize=(27,10))
df_sigma_z = pd.DataFrame(sigma_z, index = list_index)
df_sigma_z_tranposed = df_sigma_z.transpose()
df_sigma_z_tranposed=df_sigma_z_tranposed.sort_index(axis = 0,ascending = False)
df_sigma_z_tranposed=df_sigma_z_tranposed.sort_index(axis = 1,ascending = True)
ax = sns.heatmap(df_sigma_z_tranposed,annot=True,vmin=0,vmax=1)
ax.set_xlabel('aff')
ax.set_ylabel('ctot')
# Out:
# Text(308.22222222222223, 0.5, 'ctot')

# %%
plt.subplots(figsize=(10,8))
df_mean_aff = pd.DataFrame(mean_affinity, index = list_index)
df_mean_aff_tranposed = df_mean_aff.transpose()
df_mean_aff_tranposed=df_mean_aff_tranposed.sort_index(axis = 0,ascending = False)
df_mean_aff_tranposed=df_mean_aff_tranposed.sort_index(axis = 1,ascending = True)
ax = sns.heatmap(df_mean_aff_tranposed,annot=True,vmin=0,vmax=1)
ax.set_xlabel('aff')
ax.set_ylabel('ctot')
# Out:
# Text(95.72222222222221, 0.5, 'ctot')

# %%
#fig, axs = plt.subplots(5, gridspec_kw=dict(height_ratios=[5,5,5,5,5]),figsize=(30,30))
fig, axs = plt.subplots(4, gridspec_kw=dict(height_ratios=[5,5,5,5]),figsize=(15,25))

sns.heatmap(df_tranposed,ax=axs[0],annot=True,vmin=0,vmax=10)
sns.heatmap(df_act_tranposed,ax=axs[1],annot=True,vmin=0,vmax=1)
sns.heatmap(df_cfhet_tranposed, annot=True, ax=axs[2], vmin=0, vmax=1)
sns.heatmap(df_cfree_aff_eq_het_tranposed,ax=axs[3],annot=True,vmin=0,vmax=1)

#sns.heatmap(df_cfhet_aff_transposed, annot=True, ax=axs[3], vmin=0, vmax=1)
#sns.heatmap(df_cfree_aff_eq_het_tranposed,ax=axs[4],annot=True,vmin=0,vmax=1)

axs[0].set_xlabel('aff',size=15)
axs[0].set_ylabel('ctot',size=15)
axs[1].set_xlabel('aff',size=15)
axs[1].set_ylabel('ctot',size=15)
axs[2].set_xlabel('aff',size=15)
axs[2].set_ylabel('ctot',size=15)
axs[3].set_xlabel('aff',size=15)
axs[3].set_ylabel('ctot',size=15)
#axs[4].set_xlabel('aff',size=15)
#axs[4].set_ylabel('ctot',size=15)

#axs[0].set_title("Diversite sans dosage genetique",size=15)
#axs[1].set_title("Diversite avec dosage genetique",size=15)
axs[0].set_title("Diversity",size=15)
axs[1].set_title("Activity",size=15)
axs[2].set_title("cfree_het/ctot",size=15)
axs[3].set_title("cfree_het*meanaff_eq",size=15)
#axs[3].set_title("cfree_het*meanaff_0",size=15)
#axs[4].set_title("cfree_het*meanaff_eq",size=15)


#axs[0].set_text(x=-7800,y=0.55,s="A",fontweight='bold',fontsize=16)
axs[0].text(y=0,x=-1,s="A",fontsize=20)
axs[1].text(y=0,x=-1,s="B",fontsize=20)
axs[2].text(y=0,x=-1,s="C",fontsize=20)
axs[3].text(y=0,x=-1,s="D",fontsize=20)
#axs[4].text(y=0,x=-1,s="E",fontsize=20)

fig.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, gridspec_kw=dict(height_ratios=[5,5]),figsize=(20,15))

sns.heatmap(df_cfree_aff_eq_het_tranposed,ax=axs[0],annot=True,vmin=5,vmax=1)
sns.heatmap(df_cfree_aff_eq_hom_tranposed,ax=axs[1],annot=True,vmin=5,vmax=1)

axs[0].set_xlabel('aff',size=15)
axs[0].set_ylabel('ctot',size=15)
axs[1].set_xlabel('aff',size=15)
axs[1].set_ylabel('ctot',size=15)

#axs[0].set_title("Diversite sans dosage genetique",size=15)
axs[0].set_title("cfree_het*meanaff_eq",size=15)
axs[1].set_title("cfree_hom*meanaff_eq",size=15)

#axs[0].set_text(x=-7800,y=0.55,s="A",fontweight='bold',fontsize=16)
axs[0].text(y=0,x=-1,s="A",fontsize=20)
axs[1].text(y=0,x=-1,s="B",fontsize=20)

plt.show()

# %%
fig, axs = plt.subplots(2, gridspec_kw=dict(height_ratios=[5,5]),figsize=(20,15))

sns.heatmap(df_sigma_0_tranposed,ax=axs[0],annot=True,vmin=0,vmax=1)
sns.heatmap(df_sigma_z_tranposed,ax=axs[1],annot=True,vmin=0,vmax=1)

axs[0].set_xlabel('aff',size=15)
axs[0].set_ylabel('ctot',size=15)
axs[1].set_xlabel('aff',size=15)
axs[1].set_ylabel('ctot',size=15)

#axs[0].set_title("Diversite sans dosage genetique",size=15)
axs[0].set_title("sigma_0",size=15)
axs[1].set_title("sigma_z",size=15)

#axs[0].set_text(x=-7800,y=0.55,s="A",fontweight='bold',fontsize=16)
axs[0].text(y=0,x=-1,s="A",fontsize=20)
axs[1].text(y=0,x=-1,s="B",fontsize=20)

plt.show()
